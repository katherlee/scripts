# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from ED import HubbardHamiltonian

# %%
h = HubbardHamiltonian([[0, 1],[1,0]], U=5, mu=0, shift=False)
# Out:
# /home/katherlee/Research/misc_scripts/ED.py:165: RuntimeWarning: invalid value encountered in true_divide
#   tmp = np.tile(self.eigval, (self.eigval.size, 1)).astype(complex)

# %%
plt.plot(h.tau_grid, h.gtau_vals[:,0,0])
plt.plot(h.tau_grid, h.gtau_vals[:,0,1])
plt.plot(h.tau_grid, h.gtau_vals[:,0,2])
plt.plot(h.tau_grid, h.gtau_vals[:,0,3])

# %%
plt.plot(h.tau_grid, h.gtau_vals[:,2,2])
plt.plot(h.tau_grid, h.gtau_vals[:,2,3])
plt.plot(h.tau_grid, h.gtau_vals[:,3,2])
plt.plot(h.tau_grid, h.gtau_vals[:,3,3])

# %%
plt.plot(h.tau_grid, h.chi_tau_vals[:,0,0])
plt.plot(h.tau_grid, h.chi_tau_vals[:,0,1])
plt.plot(h.tau_grid, h.chi_tau_vals[:,0,2])
plt.plot(h.tau_grid, h.chi_tau_vals[:,0,3])

# %%
plt.plot(h.iwf_grid, h.giw_vals[:,0,0].real)
plt.plot(h.iwf_grid, h.giw_vals[:,0,1].real)
plt.plot(h.iwf_grid, h.giw_vals[:,1,0].real)
plt.plot(h.iwf_grid, h.giw_vals[:,1,1].real)

# %%
plt.plot(h.iwf_grid, h.giw_vals[:,0,0].imag)
plt.plot(h.iwf_grid, h.giw_vals[:,0,1].imag)
plt.plot(h.iwf_grid, h.giw_vals[:,1,0].imag)
plt.plot(h.iwf_grid, h.giw_vals[:,1,1].imag)

# %%
plt.plot(h.iwb_grid[1:], h.chi_iw_vals[1:,0,0].real, '-x')
plt.plot(h.iwb_grid[1:], h.chi_iw_vals[1:,0,1].real, '-x')
plt.plot(h.iwb_grid[1:], h.chi_iw_vals[1:,0,2].real, '-x')
plt.plot(h.iwb_grid[1:], h.chi_iw_vals[1:,0,3].real, '-x')

# %%
plt.plot(h.iwb_grid, h.chi_iw_vals[:,0,0].real, '-x')
plt.plot(h.iwb_grid, h.chi_iw_vals[:,0,1].real, '-x')
plt.plot(h.iwb_grid, h.chi_iw_vals[:,0,2].real, '-x')
plt.plot(h.iwb_grid, h.chi_iw_vals[:,0,3].real, '-x')

# %%
plt.plot(h.iwb_grid, h.chi_iw_vals[:,0,0].imag, '-x')
plt.plot(h.iwb_grid, h.chi_iw_vals[:,0,1].imag, '-x')
plt.plot(h.iwb_grid, h.chi_iw_vals[:,0,2].imag, '-x')
plt.plot(h.iwb_grid, h.chi_iw_vals[:,0,3].imag, '-x')

# %%
plt.plot(h.tau_grid, h.W_tau_vals[:,0,0])
plt.plot(h.tau_grid, h.W_tau_vals[:,0,1])
plt.plot(h.tau_grid, h.W_tau_vals[:,0,2])
plt.plot(h.tau_grid, h.W_tau_vals[:,0,3])

# %%
plt.plot(h.iwb_grid, h.W_iw_vals[:,0,0].real, '-x')
plt.plot(h.iwb_grid, h.W_iw_vals[:,0,1].real, '-x')
plt.plot(h.iwb_grid, h.W_iw_vals[:,0,2].real, '-x')
plt.plot(h.iwb_grid, h.W_iw_vals[:,0,3].real, '-x')

# %%
plt.plot(h.iwb_grid[1:], h.W_iw_vals[1:,0,0].real, '-x')
plt.plot(h.iwb_grid[1:], h.W_iw_vals[1:,0,1].real, '-x')
plt.plot(h.iwb_grid[1:], h.W_iw_vals[1:,0,2].real, '-x')
plt.plot(h.iwb_grid[1:], h.W_iw_vals[1:,0,3].real, '-x')
